# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.binomial?

# %%
l=[]
for i in range(30):
    #a = np.random.binomial(n=50, p=0.3,size=150)
    a = np.random.uniform(high=50,size=15000)
    l.append( a.mean())
    sns.displot(a, kde=True, bins=20)
    plt.xlim(0,50)
# Out:
# /home/arif/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)

# %%
sns.displot(l, kde=True, bins=20)

# %%
l
# Out:
# [0.14269983646509715,
#  0.34498542858451564,
#  8.488889207008784,
#  10.35737771922775,
#  10.08566233499305,
#  10.15555079685207,
#  9.67512830199542,
#  9.8226808618558]
